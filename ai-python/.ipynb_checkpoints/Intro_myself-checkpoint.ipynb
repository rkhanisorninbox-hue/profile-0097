# %% [markdown]
# ### 66010097

# %% [markdown]
# -----------

# %% [markdown]
# **<h2><center>Mr.Khanisorn Rimpear</center></h2>**

# %% [markdown]
# ![ภาพถ่าย](https://img2.pic.in.th/pic/IMG_1976ead40f079e81a3f4.jpeg)

# %% [markdown]
# currently study in the *<font color='purple'>Computer Engineering Department</font>* at **<font color='orange'>King Mongkut's Institute of Technology Ladkrabang (KMITL)</font>** in **<font color='blue'>Bangkok, Thailand</font>***.

# %% [markdown]
# | Year | GPA  |
# |---|---|
# | 1  | 2.25  |
# | 2  | 2.38  |
# | 3  |   |
# | 4  |   |

# %%
print("Jello World?")
# Out:
# Jello World?

# %% [markdown]
# ### **Some of Programming skill(s) I'm <font color='red'>currently</font> study**

# %% [markdown]
# - <font color='blue'> Python</font>
#    study from kaggle and udemy (introduction to python)
# - <font color='purple'> CSS</font>
#    study from udemy (built your first website in 1 week)
# - <font color='red'> HTML</font>
#    study from udemy (built your first website in 1 week and web development from scratch)
# - <font color='orange'> JSON</font>
#    study from udemy (javascript essentials)
