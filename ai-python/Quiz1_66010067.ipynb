# %%
print('66010097 Khanisorn Rimpeaar')
# Out:
# 66010097 Khanisorn Rimpeaar

# %%
for row in range(8):
    for col in range(8):
        if (row ==0 or row ==7):
            print("*", end="")
        elif (col==0 or col==7):
            print("*", end="")
        else:
            print(" ", end="")
#เลขศูนย์ 0
        if col == 7:
            print(" ",end="")
#เว้นช่องระหว่างเลข

    for col in range(8):
        if (row ==0 or row ==7 or row ==4):
            print("*", end="")
        elif (col==7):
            print("*", end="")
        elif (row==7 or row==8 or row==6) and (col==0):
            print(" ", end="")
        elif (row==1 or row==2 or row==3) and (col==0):
            print("*", end="")
        else:
            print(" ", end="")
#เลขเก้า
        if col == 7:
            print(" ",end="") 
#เว้นช่องระหว่างเลข
    
    for col in range(8):
        if (row ==0) or (col==7):
            print("*", end="")
        else:
            print(" ", end="")
#เลขเจ็ด
        if col == 7:
            print(" ",end="") 
#เว้นช่องระหว่างเลข
    
    print()
# Out:
# ******** ******** ********
# *      * *      *        *
# *      * *      *        *
# *      * *      *        *
# *      * ********        *
# *      *        *        *
# *      *        *        *
# ******** ********        *
