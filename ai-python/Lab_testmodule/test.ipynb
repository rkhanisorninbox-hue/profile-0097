# %%
import sys
sys.path
# Out:
# ['c:\\users\\nutpu\\appdata\\local\\programs\\python\\python39\\python39.zip',
#  'c:\\users\\nutpu\\appdata\\local\\programs\\python\\python39\\DLLs',
#  'c:\\users\\nutpu\\appdata\\local\\programs\\python\\python39\\lib',
#  'c:\\users\\nutpu\\appdata\\local\\programs\\python\\python39',
#  '',
#  'c:\\users\\nutpu\\appdata\\local\\programs\\python\\python39\\lib\\site-packages',
#  'c:\\users\\nutpu\\appdata\\local\\programs\\python\\python39\\lib\\site-packages\\win32',
#  'c:\\users\\nutpu\\appdata\\local\\programs\\python\\python39\\lib\\site-packages\\win32\\lib',
#  'c:\\users\\nutpu\\appdata\\local\\programs\\python\\python39\\lib\\site-packages\\Pythonwin']

# %%
c:\users\nutpu\appdata\local\programs\python\python39\lib\site-packages

# %%
import myluck
myluck.lotto(3)
# Out:
# Use from site package
# [61, 72, 39]
